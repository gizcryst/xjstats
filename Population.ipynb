# %% [markdown]
# Source: https://archive.is/bF3jc

# %%
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns
rc = {
    'figure.figsize': (20,10),
    'lines.linewidth': 3,
}
sns.set(font_scale=2, rc=rc)
# pd.options.plotting.backend = "plotly"

# %%
df = pd.read_csv('population.csv', index_col=0, usecols=range(5))

# %%
# Population breakdown by ethnicity (only translated the top 4 ethnic groups here)
df
# Out:
#        Uyghur     Han  Kazakh     Hui
# Year
# 1978   555.53  512.90   82.10   53.12
# 1980   576.46  531.03   87.68   56.56
# 1985   629.44  534.92   98.72   59.96
# 1990   724.95  574.66  113.92   68.89
# 1995   780.00  631.81  123.77   74.76
# 2000   852.33  725.08  131.87   83.93
# 2001   860.56  742.20  131.92   84.42
# 2002   869.23  759.57  133.35   85.46
# 2003   882.35  771.10  135.21   86.67
# 2004   897.67  780.25  138.16   87.63
# 2005   923.50  795.66  141.39   89.35
# 2006   941.38  812.16  143.50   90.96
# 2007   965.06  823.93  148.39   94.30
# 2008   983.18  836.33  151.05   95.30
# 2009  1001.98  841.69  151.48   98.04
# 2010  1017.15  832.29  151.16   98.40
# 2011  1037.04  844.42  154.26  100.34
# 2012  1052.86  847.29  155.75  102.31
# 2013  1074.41  860.06  158.54  104.57
# 2014  1127.19  859.51  159.87  105.85
# 2015  1130.33  861.10  159.12  101.58
# 2016  1144.90  826.95  158.67  102.01
# 2017  1165.50  790.18  158.36  101.99
# ...

# %%
# Population graph
df.plot()

# %%
# Growth rate
change = df.pct_change() * 100

# %%
# Growth rate graph
change.plot()
